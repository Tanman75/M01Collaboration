# %%
seconds_per_hour = (60 * 60)
print(seconds_per_hour)
seconds_per_day = seconds_per_hour * 24
print (seconds_per_day)
a = seconds_per_day / seconds_per_hour
b = seconds_per_day // seconds_per_hour

print(a)
print(b)
#the change in floating-point and integer is floating will come with an decimal showing it can do more than just whole numbers but other than that nothing has changed.
# Out:
# 3600
# 86400
# 24.0
# 24
